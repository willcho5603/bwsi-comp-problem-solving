# %% [markdown]
# # Supervised Learning: Types of Supervised Learning

# %% [markdown]
# # Classification 🏷️

# %% [markdown]
# ### Support Vector Machines
# - Start the section with a plot of two distinct clusters, linearly separated
# - Prompt a discussion about how the students would classify the points and explain their reasoning
# - Repeat with a non linear example (maybe 3 clusters that spiral or something similar)
# - This is the intuition for SVMs!
#
# Additional content/references:
# - [Wikipedia article](https://en.wikipedia.org/wiki/Support_vector_machine)
# - Helpful GeeksforGeeks notes [here](https://www.geeksforgeeks.org/machine-learning/support-vector-machine-algorithm/)
# - Focus on the mathematical concepts in words
# - Define hyperplane in simple words (i.e. in 2D, it's just a linear boundary line)
# - Simple equation: $w^Tx + b = 0$
#     - $w$ is the normal vector to the hyperplane (the direction perpendicular to it)
#     - $b$ is the offset or bias term representing the distance of the hyperplane from the origin along the normal vector
# - pros/cons summarized [here](https://scikit-learn.org/stable/modules/svm.html)

# %% [markdown]
# ## K-Nearest Neighbors
# - GeeksforGeeks [reference](https://www.geeksforgeeks.org/machine-learning/k-nearest-neighbours/)
# - Include "pseudo code" or a summary of the algorithm steps in words
# - Requires careful selection of $k$ and the distance metric!
# - Voting scheme have issues if the distribution is skewed ([source](https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm#:~:text=A%20drawback%20of%20the%20basic%20%22majority%20voting%22%20classification%20occurs%20when%20the%20class%20distribution%20is%20skewed.%20That%20is%2C%20examples%20of%20a%20more%20frequent%20class%20tend%20to%20dominate%20the%20prediction%20of%20the%20new%20example%2C%20because%20they%20tend%20to%20be%20common%20among%20the%20k%20nearest%20neighbors%20due%20to%20their%20large%20number.))

# %% [markdown]
# ----
# ## Regression 📈

# %% [markdown]
# ### Linear Regression
#
# - Helpful Geeksforgeeks [reference](https://www.geeksforgeeks.org/machine-learning/ml-linear-regression/)
# - Simple linear regression (we already learned this in Module 1!)
# - Multiple linear regression:
#     - $y = w_0 + w_1 x_1 + w_2 x_2 + ... + w_n x_n$
#     - where $x_1 ... x_n$ are the inputs and $w_0 ... w_n$ are the weights
# - Comment on the assumptions made with linear regression and its pros/cons

# %% [markdown]
# <p align="left">
#     <img src = "https://media.geeksforgeeks.org/wp-content/uploads/20250729145749642923/Types-of-Linear-Regression.webp" width = "500">
# </p>

# %% [markdown]
# ## Non linear regression
# - Discussion from sklearn docs [here](https://scikit-learn.org/stable/auto_examples/svm/plot_svm_regression.html#sphx-glr-auto-examples-svm-plot-svm-regression-py)
# - Brief comments/overview from notes [here](https://www.geeksforgeeks.org/machine-learning/non-linear-regression-examples-ml/#nonlinear-regression-in-machine-learning)
# - Maybe just a plot/visual example but doesn't need to be in depth!

# %% [markdown]
# ### Performance Metrics for Linear Regression
# - Mean absolute error (MAE) and mean squared error (MSE) are the most common metrics
# - Provide lecture material and the formulas for each
# - Comment on the strengths/weaknesses of each
# - There is a problem if your model does not produce normally distributed errors!
#
# <p align="left">
#     <img src = "https://media.geeksforgeeks.org/wp-content/uploads/20231123113103/python-linear-regression-5.png" width = "400">
# </p>

# %% [markdown]
# ## Summary 📚
