# %% [markdown]
# # Final Project: Overview

# %% [markdown]
# - All in class
# - Approx 2 hours in small groups
# - Instructor guidance
# - Open ended scenarios tailored for a particular algorithm

# %% [markdown]
# ## Problem 1

# %% [markdown]
# ## Problem 2

# %% [markdown]
# ## Problem 3

# %% [markdown]
# ## Problem 4

# %% [markdown]
# ## Problem 5

# %% [markdown]
# ## Problem 6
